# %%
from sympy import *
init_printing()

# %%
x = Symbol('x',real=True)
y = Function('y')
integrate((3*x*cos(x)+3*sin(x))/sqrt(1+(3*x*sin(x))**2),x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-69ba7c44078e> in <module>
#       1 x = Symbol('x',real=True)
#       2 y = Function('y')
# ----> 3 integrate((3*x*cos(x)+3*sin(x))/sqrt(1+(3*x*sin(x))**2),x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in integrate(*args, **kwargs)
#    1463     if isinstance(integral, Integral):
#    1464         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1465                              risch=risch, manual=manual)
#    1466     else:
#    1467         return integral
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     536                 else:
#     537                     antideriv = self._eval_integral(
# --> 538                         function, xab[0], **eval_kwargs)
# ...

# %%
dsolve?
